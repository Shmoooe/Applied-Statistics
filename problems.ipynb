# %% [markdown]
# # Problems
#
# This is my assessment submission to demonstrate that I have achieved the learning outcomes of the module Applied Statistics, with the lecturer Ian McLoughlin.
#
# Author: Joanna Kelly

# %% [markdown]
# ## Problem 1: Extending the Lady Tasting Tea

# %% [markdown]
# ## Problem 2: Normal Distribution

# %% [markdown]
# ## Problem 3: t-Tests

# %% [markdown]
# ## Problem 4: ANOVA

# %% [markdown]
# # End
